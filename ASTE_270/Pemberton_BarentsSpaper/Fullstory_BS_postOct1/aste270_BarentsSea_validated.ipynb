# %% [markdown]
# ### Introduction
#
# The goal of this notebook will be to validate the Barents Sea M term for the full ASTE 270 setup.
#
# Goals:
# - start by checking that the gateways in bravingthebarentsSeaMterm_10_16.ipynb are at least realistic with the convergence of the other J terms
# - load the G terms and J terms for 2007 as we have saved previously
# - plot these
# - calculate the G and J terms as An has described with binwidthT1 and binwidthS1
# - see if we can plot these similarly.
# - prove that heat transport as shown by the gates is the same as heat transport through the gates themselves.
#
# On second thought I'm wondering if we can start with this in the ASTE 90 plot.
# Can we
# - compare the change in volume to the overall change J terms
# - compare the volume transport as represented by the gates to the volume transport in TS space?
